# %% [markdown]
# ### MAIN CODE

# %% [markdown]
# #### IMPORTS

# %%
import hashlib as hl
import json
import datetime as dt
import uuid

# %% [markdown]
# #### BOOK

# %%
class Book:
    # CLASS ATTRIBUTE
    ALL_BOOKS: list = []

    # CONSTRUCTOR
    def __init__(self, isbn: str, title: str, author: str, quantity: int, price: float, genre=[]) -> None:
        self.isbn: str = isbn
        self.title: str = title
        self.author: str = author
        self.quantity: int = quantity
        self.price: float = price
        self.genre: list = [*genre]

        print(f"Adding {self.quantity} copies of {self.title} to the library")
        Book.ALL_BOOKS.append(self)

    # METHODS:

    def getInfo(self):
        return f"{self.title} by {self.author} ({self.isbn}) - {self.quantity} copies available"

    def updateInfo(self, **kwargs):
        for key, value in kwargs.items():
            if hasattr(self, key):
                setattr(self, key, value)
            else:
                print(f"Invalid attribute: {key}")

    # CLASS METHODS:

    @classmethod
    def from_json(cls, json_data):
        isbn: str = json_data.get("isbn")
        title: str = json_data.get("title")
        author: str = json_data.get("author")
        quantity: int = json_data.get("quantity")
        price: float = json_data.get("price")
        genre: list = json_data.get("genre").split(
            "|") if json_data.get("genre") else []
        return cls(isbn, title, author, quantity, price, genre)

    @classmethod
    def from_file(cls, file_path):
        with open(file_path, "r") as file:
            all_books = json.load(file)
        return [cls.from_json(book) for book in all_books]

        # DUNDERS:

# %% [markdown]
# #### USER

# %%
class UserAccount:
    # CLASS ATTRIBUTE
    ALL_USERS = []

    # CONSTRUCTOR
    def __init__(self, name: str, email: str, pin: int, address: str, phone: str, guid: str) -> None:
        self.__guid: str = guid
        self.__name: str = name
        self.__email: str = email
        self.__pin: str = UserAccount.encrypt_pin(pin)
        self.address: str = address
        self.phone: str = phone
        self.__balance: float = 0
        self.__LOGGED_IN: bool = False
        self.ALL_USERS.append(self)

    # GETTERS
    def get_name(self): return self.__name
    def get_email(self): return self.__email
    def get_pin(self): return self.__pin
    def get_balance(self): return self.__balance
    def get_logged_in_status(self): return self.__LOGGED_IN
    def get_guid(self): return self.__guid

    # SETTERS
    def set_name(self, name: str) -> None:
        self.__name = name

    def set_email(self, email: str) -> None:
        self.__email = email

    def set_pin(self, pin: int) -> None:
        self.__pin = UserAccount.encrypt_pin(pin)

    def set_balance(self, balance: float) -> None:
        self.__balance = balance

    def set_logged_in_status(self, status: bool) -> None:
        self.__LOGGED_IN = status

    def set_guid(self, guid: str) -> None:
        self.__guid = guid

    # PROPERTIES
    name = property(get_name, set_name)
    email = property(get_email, set_email)
    pin = property(get_pin, set_pin)
    balance = property(get_balance, set_balance)
    logged_in = property(get_logged_in_status)
    guid = property(get_guid, set_guid)

    # METHODS
    def logout(self) -> None:
        self.__LOGGED_IN = False
        print(f"Logged out from {self.__name} successfully")

    # CLASS METHODS
    @classmethod
    def login(cls, email: str, pin: int) -> object:
        for user in cls.ALL_USERS:
            if user.get_email() == email:
                if user.get_pin() == UserAccount.encrypt_pin(pin):
                    user.set_logged_in_status(True)
                    print(f"Logged in to {user.get_name()} successfully")
                    return user
                else:
                    print("Invalid PIN")
                    return None
        print("Invalid Email")
        return None

    @classmethod
    def get_all_users(cls) -> list:
        return cls.ALL_USERS

    @classmethod
    def get_user_by_email(cls, email: str) -> object:
        for user in cls.ALL_USERS:
            if user.email == email:
                return user
        return None

    # STATIC METHODS

    @staticmethod
    def encrypt_pin(pin: int) -> str:
        return hl.sha256(str(pin).encode()).hexdigest()

    # DUNDERS

# %%
class Customer(UserAccount):
    # CLASS ATTRIBUTE
    ALL_CUSTOMERS = []

    # CONSTRUCTOR
    def __init__(self, name: str, email: str, pin: int, address: str, phone: str, customer_type: str, guid: str) -> None:
        super().__init__(name, email, pin, address, phone, guid)
        self.__customer_type = customer_type
        Customer.ALL_CUSTOMERS.append(self)

    # GETTERS

    def get_customer_type(self) -> str:
        return self.__customer_type

    # SETTERS

    def set_customer_type(self, type: str) -> None:
        self.__customer_type = type

    # METHODS

    # CLASS METHODS

    @classmethod
    def get_all_customers(cls) -> list:
        return cls.ALL_CUSTOMERS

    @classmethod
    def get_customer_by_email(cls, email: str) -> object:
        for customer in cls.ALL_CUSTOMERS:
            if customer.get_email() == email:
                return customer
        return None

    @classmethod
    def from_json(cls, json: dict) -> object:
        return cls(json['name'], json['email'], json['pin'], json['address'], json['phone'], json['type'], json['guid'])

    @classmethod
    def from_file(cls, file: str) -> None:
        with open(file, 'r') as f:
            all_customers = json.load(f)
        return [cls.from_json(customer) for customer in all_customers]

# %% [markdown]
# #### EMPLOYEE

# %%
class Employee(UserAccount):
    #  CLASS ATTRIBUTES
    ALL_EMPLOYEES: list = []
    ALL_EMPLOYEES_DICT: dict = {}

    # CONSTRUCTOR
    def __init__(self, name: str, email: str, pin: int, address: str, phone: str, designation: str) -> None:
        super().__init__(name, email, pin, address, phone)
        self.designation: str = designation
        Employee.ALL_EMPLOYEES.append(self)
        Employee.ALL_EMPLOYEES_DICT[designation] = [self] if designation not in Employee.ALL_EMPLOYEES_DICT else [
            *Employee.ALL_EMPLOYEES_DICT[designation], self]
        
    # METHODS
    def processOder():
        pass

    def updateStock():
        pass

    def generateSalesReport():
        pass


    # DUNDERS

# %% [markdown]
# #### SHOPPINGCART

# %%
class ShoppingCart:
    def __init__(self):
        self.items: list[Book] = []

    def add_item(self, it):
        self.items.append(it)

    def remove_item(self, it):
        self.items.remove(it)

    def total(self):
        return sum(list(map(lambda x: x.price, self.items)))

    def __repr__(self):
        return f"Cart with {len(self.items)} items."

# %% [markdown]
# #### ORDER

# %%
class Order:
    ALL_ORDERS = []
    def __init__(self, ordered_by: Customer):
        self.order = []
        self.order_id = uuid.uuid4()
        self.ordered_by: Customer = ordered_by
        self.order_status = 'PENDING'
        self.order_date = dt.datetime.now()
        self.approved_by: Employee | None = None

    def add_item(self, cart: ShoppingCart):
        self.order.append(cart)

# %% [markdown]
# #### BOOKSTORE

# %%
class BookStore:
    # CLASS VARIABLES:

    # CONSTUCTOR:
    def __init__(self, name, address):
        self.name: str = name
        self.address: str = address
        self.inventory = []
        self.__inventory = []
        self.__customers: list = []
        self.__orders: list = []
        self.__employees: list = []

    # GETTERS:
    def get_inventory(self): return self.__inventory
    def get_customers(self): return self.__customers
    def get_orders(self): return self.__orders
    def get_employees(self): return self.__employees

    # SETTERS:
    def set_inventory(self, inventory): self.__inventory = inventory
    def set_customers(self, customers): self.__customers = customers
    def set_orders(self, orders): self.__orders = orders
    def set_employees(self, employees): self.__employees = employees

    # METHODS:

    def updateStore(self):
        self.inventory = self.__inventory

    def reload(self):
        self.inventory = Book.ALL_BOOKS
        self.__inventory = self.inventory
        self.__customers = Customer.ALL_CUSTOMERS

    def addBook(self, book):
        self.inventory.append(book)

    def removeBook(self, book):
        if book in self.__inventory:
            self.__inventory.remove(book)

    def searchBook(self, searchBy, value):
        for book in self.inventory:
            if getattr(book, searchBy) == value:
                return book
        return None

    def filterBy(self, filterBy, value):
        filtered_books = []
        for book in self.inventory:
            if getattr(book, filterBy) == value:
                filtered_books.append(book)
        return filtered_books

    def addUser(self, user):
        match user:
            case Customer():
                self.customers.append(user)
            case Employee():
                self.employees.append(user)
            case _:
                print("Invalid user type")

    def removeUser(self, user):
        if user in self.customers:
            self.customers.remove(user)
        elif user in self.employees:
            self.employees.remove(user)

# %% [markdown]
# ### DRIVER CODE

# %%
# CREATE A BOOKSTORE
TheBookStore = BookStore("The Book Store", 'BracU')

# LOAD ALL BOOKS FROM JSON FILE
Book.from_file('./data/books.json')

# LOAD ALL CUSTOMERS FROM JSON FILE
Customer.from_file('./data/customers.json')

# RELOAD THE BOOKS AND CUSTOMERS
TheBookStore.reload()

myAccount = Customer.login('acomello2@engadget.com', '418324')
# Out:
# Adding 27 copies of Macaca mulatta to the library
# Adding 17 copies of Thalasseus maximus to the library
# Adding 2 copies of Eolophus roseicapillus to the library
# Adding 86 copies of Phalacrocorax carbo to the library
# Adding 34 copies of Neophron percnopterus to the library
# Adding 66 copies of Felis chaus to the library
# Adding 26 copies of Equus hemionus to the library
# Adding 95 copies of Canis dingo to the library
# Adding 29 copies of Cordylus giganteus to the library
# Adding 71 copies of Papio cynocephalus to the library
# Adding 45 copies of Marmota monax to the library
# Adding 38 copies of Eudromia elegans to the library
# Adding 30 copies of Phoeniconaias minor to the library
# Adding 39 copies of Gyps fulvus to the library
# Adding 6 copies of Eudromia elegans to the library
# Adding 34 copies of Varanus komodensis to the library
# Adding 24 copies of Porphyrio porphyrio to the library
# Adding 49 copies of Sus scrofa to the library
# Adding 84 copies of Cebus apella to the library
# Adding 21 copies of Corallus hortulanus cooki to the library
# Adding 34 copies of Castor fiber to the library
# Adding 11 copies of Lamprotornis sp. to the library
# Adding 54 copies of Picoides pubescens to the library
# Adding 37 copies of Phalacrocorax carbo to the library
# Adding 29 copies of Dendrohyrax brucel to the library
# Adding 19 copies of Phascogale tapoatafa to the library
# Adding 13 copies of Dusicyon thous to the library
# Adding 37 copies of Gopherus agassizii to the library
# Adding 24 copies of Alligator mississippiensis to the library
# Adding 45 copies of Isoodon obesulus to the library
# Adding 69 copies of Agkistrodon piscivorus to the library
# Adding 53 copies of Galago crassicaudataus to the library
# Adding 87 copies of Equus hemionus to the library
# Adding 91 copies of Galictis vittata to the library
# Adding 11 copies of Epicrates cenchria maurus to the library
# Adding 81 copies of Madoqua kirkii to the library
# Adding 22 copies of Smithopsis crassicaudata to the library
# Adding 16 copies of Microcebus murinus to the library
# Adding 8 copies of Lepus arcticus to the library
# Adding 27 copies of Anitibyx armatus to the library
# Adding 81 copies of Phalacrocorax varius to the library
# Adding 57 copies of Loris tardigratus to the library
# Adding 49 copies of Physignathus cocincinus to the library
# Adding 40 copies of Varanus sp. to the library
# Adding 78 copies of Ammospermophilus nelsoni to the library
# Adding 96 copies of Morelia spilotes variegata to the library
# Adding 46 copies of Anhinga rufa to the library
# Adding 76 copies of Eira barbata to the library
# Adding 39 copies of Anastomus oscitans to the library
# Adding 76 copies of Myrmecophaga tridactyla to the library
# Adding 13 copies of Nyctea scandiaca to the library
# Adding 12 copies of Sterna paradisaea to the library
# Adding 61 copies of Ramphastos tucanus to the library
# Adding 51 copies of Equus burchelli to the library
# Adding 34 copies of Lutra canadensis to the library
# Adding 32 copies of Ara macao to the library
# Adding 91 copies of Varanus sp. to the library
# Adding 75 copies of Kobus leche robertsi to the library
# Adding 56 copies of Cracticus nigroagularis to the library
# Adding 24 copies of Ursus arctos to the library
# Adding 70 copies of Canis lupus baileyi to the library
# Adding 90 copies of Scolopax minor to the library
# Adding 49 copies of Butorides striatus to the library
# Adding 27 copies of Papio ursinus to the library
# Adding 49 copies of Irania gutteralis to the library
# Adding 73 copies of Zosterops pallidus to the library
# Adding 41 copies of Mycteria leucocephala to the library
# Adding 39 copies of Dasyurus maculatus to the library
# Adding 80 copies of Anas punctata to the library
# Adding 38 copies of Ciconia episcopus to the library
# Adding 54 copies of Sciurus vulgaris to the library
# Adding 31 copies of Dicrurus adsimilis to the library
# Adding 21 copies of Orcinus orca to the library
# Adding 44 copies of Microcebus murinus to the library
# Adding 11 copies of Chlidonias leucopterus to the library
# Adding 72 copies of Macropus parryi to the library
# Adding 97 copies of Phoeniconaias minor to the library
# Adding 30 copies of Isoodon obesulus to the library
# Adding 22 copies of Eurocephalus anguitimens to the library
# Adding 20 copies of Ratufa indica to the library
# Adding 77 copies of Kobus leche robertsi to the library
# Adding 15 copies of Colobus guerza to the library
# Adding 67 copies of Acrantophis madagascariensis to the library
# Adding 6 copies of Colaptes campestroides to the library
# Adding 50 copies of Phasianus colchicus to the library
# Adding 82 copies of Eubalaena australis to the library
# Adding 50 copies of Tachyglossus aculeatus to the library
# Adding 53 copies of Raphicerus campestris to the library
# Adding 50 copies of Boa caninus to the library
# Adding 12 copies of Naja nivea to the library
# Adding 86 copies of Vulpes cinereoargenteus to the library
# Adding 37 copies of Bradypus tridactylus to the library
# Adding 77 copies of Vulpes vulpes to the library
# Adding 27 copies of unavailable to the library
# Adding 16 copies of Cercopithecus aethiops to the library
# Adding 48 copies of Choloepus hoffmani to the library
# Adding 84 copies of Anastomus oscitans to the library
# Adding 35 copies of Carduelis uropygialis to the library
# Adding 85 copies of Sarcophilus harrisii to the library
# Adding 2 copies of Ovis dalli stonei to the library
# Adding 89 copies of Manouria emys to the library
# Adding 2 copies of Stenella coeruleoalba to the library
# Adding 11 copies of Ictonyx striatus to the library
# Adding 71 copies of Cereopsis novaehollandiae to the library
# Adding 80 copies of Kobus defassa to the library
# Adding 77 copies of Grus antigone to the library
# Adding 74 copies of Paraxerus cepapi to the library
# Adding 40 copies of Macropus rufogriseus to the library
# Adding 4 copies of Cynomys ludovicianus to the library
# Adding 30 copies of Dicrostonyx groenlandicus to the library
# Adding 65 copies of Phascogale calura to the library
# Adding 27 copies of Macaca radiata to the library
# Adding 90 copies of Fratercula corniculata to the library
# Adding 51 copies of Cathartes aura to the library
# Adding 28 copies of Cebus nigrivittatus to the library
# Adding 5 copies of Sylvicapra grimma to the library
# Adding 55 copies of unavailable to the library
# Adding 48 copies of unavailable to the library
# Adding 90 copies of unavailable to the library
# Adding 76 copies of Pseudalopex gymnocercus to the library
# Adding 12 copies of Diomedea irrorata to the library
# Adding 21 copies of Bison bison to the library
# Adding 21 copies of Cervus unicolor to the library
# Adding 46 copies of Acridotheres tristis to the library
# Adding 10 copies of Ephipplorhynchus senegalensis to the library
# Adding 97 copies of Picoides pubescens to the library
# Adding 47 copies of Cereopsis novaehollandiae to the library
# Adding 55 copies of Tetracerus quadricornis to the library
# Adding 55 copies of Phacochoerus aethiopus to the library
# Adding 65 copies of Fratercula corniculata to the library
# Adding 63 copies of Centrocercus urophasianus to the library
# Adding 41 copies of Eudromia elegans to the library
# Adding 29 copies of Rhabdomys pumilio to the library
# Adding 98 copies of Leprocaulinus vipera to the library
# Adding 70 copies of Macaca radiata to the library
# Adding 39 copies of Morelia spilotes variegata to the library
# Adding 19 copies of Oxybelis sp. to the library
# Adding 52 copies of Terrapene carolina to the library
# Adding 48 copies of Erethizon dorsatum to the library
# Adding 97 copies of Macaca radiata to the library
# Adding 15 copies of Oreamnos americanus to the library
# Adding 24 copies of Rhabdomys pumilio to the library
# Adding 32 copies of Colobus guerza to the library
# Adding 97 copies of Macaca mulatta to the library
# Adding 63 copies of Tadorna tadorna to the library
# Adding 20 copies of Petaurus norfolcensis to the library
# Adding 67 copies of Chlidonias leucopterus to the library
# Adding 34 copies of Oryx gazella to the library
# Adding 48 copies of Paraxerus cepapi to the library
# Adding 28 copies of Papio cynocephalus to the library
# Adding 59 copies of Sciurus niger to the library
# Adding 34 copies of Parus atricapillus to the library
# Adding 20 copies of Pelecans onocratalus to the library
# Adding 15 copies of Vanessa indica to the library
# Adding 78 copies of Lycosa godeffroyi to the library
# Adding 61 copies of Lasiorhinus latifrons to the library
# Adding 62 copies of Hystrix cristata to the library
# Adding 21 copies of Haliaeetus leucoryphus to the library
# Adding 81 copies of Hymenolaimus malacorhynchus to the library
# Adding 98 copies of Tapirus terrestris to the library
# Adding 34 copies of Alcelaphus buselaphus cokii to the library
# Adding 1 copies of Acanthaster planci to the library
# Adding 78 copies of Porphyrio porphyrio to the library
# Adding 89 copies of Ramphastos tucanus to the library
# Adding 43 copies of Dusicyon thous to the library
# Adding 89 copies of Sus scrofa to the library
# Adding 4 copies of Connochaetus taurinus to the library
# Adding 54 copies of Phoca vitulina to the library
# Adding 77 copies of Kobus leche robertsi to the library
# Adding 39 copies of Kobus leche robertsi to the library
# Adding 67 copies of Alouatta seniculus to the library
# Adding 31 copies of Cervus unicolor to the library
# Adding 43 copies of Centrocercus urophasianus to the library
# Adding 52 copies of Axis axis to the library
# Adding 12 copies of Bucephala clangula to the library
# Adding 82 copies of Mirounga leonina to the library
# Adding 1 copies of Ursus americanus to the library
# Adding 51 copies of Spermophilus parryii to the library
# Adding 66 copies of Phalacrocorax niger to the library
# Adding 25 copies of Genetta genetta to the library
# Adding 77 copies of Vanellus armatus to the library
# Adding 38 copies of Globicephala melas to the library
# Adding 47 copies of unavailable to the library
# Adding 15 copies of Geochelone elephantopus to the library
# Adding 89 copies of Rana sp. to the library
# Adding 36 copies of Gekko gecko to the library
# Adding 66 copies of Redunca redunca to the library
# Adding 55 copies of Procyon cancrivorus to the library
# Adding 57 copies of Nasua narica to the library
# Adding 40 copies of Sterna paradisaea to the library
# Adding 41 copies of Macropus fuliginosus to the library
# Adding 12 copies of Pseudocheirus peregrinus to the library
# Adding 15 copies of Crotalus triseriatus to the library
# Adding 38 copies of Lama glama to the library
# Adding 91 copies of Paraxerus cepapi to the library
# Adding 9 copies of Uraeginthus angolensis to the library
# Adding 83 copies of Alectura lathami to the library
# Adding 27 copies of Amblyrhynchus cristatus to the library
# Adding 79 copies of Anathana ellioti to the library
# Adding 5 copies of Speothos vanaticus to the library
# Adding 81 copies of Axis axis to the library
# Adding 4 copies of Eumetopias jubatus to the library
# Adding 47 copies of Drymarchon corias couperi to the library
# Adding 95 copies of Ciconia episcopus to the library
# Adding 26 copies of Phoenicopterus ruber to the library
# Adding 24 copies of Felis yagouaroundi to the library
# Adding 10 copies of Pitangus sulphuratus to the library
# Adding 54 copies of Dipodomys deserti to the library
# Adding 65 copies of Ciconia episcopus to the library
# Adding 83 copies of unavailable to the library
# Adding 52 copies of Sciurus vulgaris to the library
# Adding 28 copies of Chlidonias leucopterus to the library
# Adding 17 copies of Francolinus coqui to the library
# Adding 45 copies of Diomedea irrorata to the library
# Adding 29 copies of Haliaetus leucogaster to the library
# Adding 48 copies of Bubalus arnee to the library
# Adding 75 copies of Acrobates pygmaeus to the library
# Adding 55 copies of Ciconia episcopus to the library
# Adding 94 copies of Theropithecus gelada to the library
# Adding 52 copies of Funambulus pennati to the library
# Adding 38 copies of Petaurus breviceps to the library
# Adding 32 copies of Gymnorhina tibicen to the library
# Adding 39 copies of Eurocephalus anguitimens to the library
# Adding 53 copies of Phoenicopterus ruber to the library
# Adding 23 copies of Dicrurus adsimilis to the library
# Adding 66 copies of Tachybaptus ruficollis to the library
# Adding 16 copies of Podargus strigoides to the library
# Adding 11 copies of Anser anser to the library
# Adding 17 copies of Coluber constrictor to the library
# Adding 56 copies of Cercopithecus aethiops to the library
# Adding 45 copies of Amazona sp. to the library
# Adding 6 copies of Felis caracal to the library
# Adding 24 copies of Agkistrodon piscivorus to the library
# Adding 42 copies of Butorides striatus to the library
# Adding 1 copies of Plegadis falcinellus to the library
# Adding 86 copies of Hippotragus niger to the library
# Adding 71 copies of Ovis ammon to the library
# Adding 39 copies of Phalaropus fulicarius to the library
# Adding 61 copies of Cebus nigrivittatus to the library
# Adding 83 copies of Philetairus socius to the library
# Adding 19 copies of Sus scrofa to the library
# Adding 29 copies of Acanthaster planci to the library
# Adding 40 copies of Ovis canadensis to the library
# Adding 66 copies of Zenaida asiatica to the library
# Adding 56 copies of Dicrurus adsimilis to the library
# Adding 79 copies of Uraeginthus granatina to the library
# Adding 34 copies of Buteo regalis to the library
# Adding 1 copies of Tamandua tetradactyla to the library
# Adding 25 copies of Papio cynocephalus to the library
# Adding 55 copies of Trachyphonus vaillantii to the library
# Adding 25 copies of Haliaeetus leucocephalus to the library
# Adding 78 copies of Uraeginthus bengalus to the library
# Adding 54 copies of Libellula quadrimaculata to the library
# Adding 6 copies of Cathartes aura to the library
# Adding 33 copies of Ammospermophilus nelsoni to the library
# Adding 74 copies of Alcelaphus buselaphus caama to the library
# Adding 17 copies of unavailable to the library
# Adding 94 copies of Phascogale tapoatafa to the library
# Adding 4 copies of Aquila chrysaetos to the library
# Adding 56 copies of Milvago chimachima to the library
# Adding 5 copies of Papio ursinus to the library
# Adding 67 copies of Lamprotornis superbus to the library
# Adding 75 copies of Felis concolor to the library
# Adding 45 copies of Genetta genetta to the library
# Adding 97 copies of Ictonyx striatus to the library
# Adding 5 copies of Hyaena hyaena to the library
# Adding 47 copies of Macaca radiata to the library
# Adding 66 copies of Genetta genetta to the library
# Adding 64 copies of Kobus leche robertsi to the library
# Adding 28 copies of Lorythaixoides concolor to the library
# Adding 9 copies of Neophoca cinerea to the library
# Adding 58 copies of Marmota monax to the library
# Adding 43 copies of Snycerus caffer to the library
# Adding 74 copies of unavailable to the library
# Adding 20 copies of Vanellus sp. to the library
# Adding 2 copies of Alligator mississippiensis to the library
# Adding 4 copies of Eunectes sp. to the library
# Adding 1 copies of Procyon lotor to the library
# Adding 63 copies of Spheniscus mendiculus to the library
# Adding 95 copies of Acinynox jubatus to the library
# Adding 12 copies of Himantopus himantopus to the library
# Adding 78 copies of Libellula quadrimaculata to the library
# Adding 83 copies of Limnocorax flavirostra to the library
# Adding 29 copies of Pseudocheirus peregrinus to the library
# Adding 35 copies of Hymenolaimus malacorhynchus to the library
# Adding 7 copies of Parus atricapillus to the library
# Adding 85 copies of Sauromalus obesus to the library
# Adding 81 copies of Pavo cristatus to the library
# Adding 94 copies of Eremophila alpestris to the library
# Adding 63 copies of Dusicyon thous to the library
# Adding 11 copies of Mungos mungo to the library
# Adding 40 copies of Neophoca cinerea to the library
# Adding 71 copies of Tringa glareola to the library
# Adding 98 copies of Vulpes chama to the library
# Adding 51 copies of Ara ararauna to the library
# Adding 50 copies of Canis lupus lycaon to the library
# Adding 5 copies of Genetta genetta to the library
# Adding 88 copies of Spermophilus parryii to the library
# Adding 92 copies of Spheniscus magellanicus to the library
# Adding 63 copies of Paroaria gularis to the library
# Adding 24 copies of Phalacrocorax carbo to the library
# Adding 21 copies of Uraeginthus angolensis to the library
# Adding 98 copies of Buteo regalis to the library
# Adding 96 copies of Cebus nigrivittatus to the library
# Adding 1 copies of Ictonyx striatus to the library
# Adding 100 copies of Melanerpes erythrocephalus to the library
# Adding 38 copies of Felis silvestris lybica to the library
# Adding 72 copies of Hydrochoerus hydrochaeris to the library
# Adding 13 copies of Ara chloroptera to the library
# Adding 15 copies of Macropus agilis to the library
# Adding 19 copies of Castor canadensis to the library
# Adding 20 copies of Naja haje to the library
# Adding 16 copies of Chelodina longicollis to the library
# Adding 66 copies of unavailable to the library
# Adding 59 copies of Tachyglossus aculeatus to the library
# Adding 28 copies of Philetairus socius to the library
# Adding 2 copies of Columba livia to the library
# Adding 74 copies of Creagrus furcatus to the library
# Adding 98 copies of Panthera leo to the library
# Adding 26 copies of Pedetes capensis to the library
# Adding 65 copies of Uraeginthus granatina to the library
# Adding 79 copies of Anitibyx armatus to the library
# Adding 13 copies of Naja sp. to the library
# Adding 77 copies of Sus scrofa to the library
# Adding 8 copies of Phascogale calura to the library
# Adding 48 copies of Uraeginthus angolensis to the library
# Adding 80 copies of Eubalaena australis to the library
# Adding 71 copies of Ovis dalli stonei to the library
# Adding 65 copies of Ceryle rudis to the library
# Adding 31 copies of Libellula quadrimaculata to the library
# Adding 34 copies of Varanus albigularis to the library
# Adding 57 copies of Spermophilus armatus to the library
# Adding 11 copies of Canis mesomelas to the library
# Adding 88 copies of Climacteris melanura to the library
# Adding 25 copies of Delphinus delphis to the library
# Adding 10 copies of Hippotragus equinus to the library
# Adding 7 copies of Tiliqua scincoides to the library
# Adding 59 copies of Alopochen aegyptiacus to the library
# Adding 37 copies of Butorides striatus to the library
# Adding 27 copies of Snycerus caffer to the library
# Adding 92 copies of Litrocranius walleri to the library
# Adding 1 copies of Nyctereutes procyonoides to the library
# Adding 66 copies of Cereopsis novaehollandiae to the library
# Adding 57 copies of Dasyurus viverrinus to the library
# Adding 83 copies of Corvus brachyrhynchos to the library
# Adding 57 copies of Lorythaixoides concolor to the library
# Adding 23 copies of Amblyrhynchus cristatus to the library
# Adding 87 copies of Agkistrodon piscivorus to the library
# Adding 11 copies of Naja nivea to the library
# Adding 58 copies of Ctenophorus ornatus to the library
# Adding 92 copies of Manouria emys to the library
# Adding 63 copies of Pteropus rufus to the library
# Adding 87 copies of Myiarchus tuberculifer to the library
# Adding 51 copies of Vanellus armatus to the library
# Adding 27 copies of Gyps bengalensis to the library
# Adding 47 copies of Madoqua kirkii to the library
# Adding 99 copies of Vulpes chama to the library
# Adding 66 copies of Choloepus hoffmani to the library
# Adding 91 copies of Crotalus cerastes to the library
# Adding 44 copies of Scolopax minor to the library
# Adding 2 copies of Eudyptula minor to the library
# Adding 7 copies of Eumetopias jubatus to the library
# Adding 51 copies of Panthera leo persica to the library
# Adding 3 copies of Spizaetus coronatus to the library
# Adding 39 copies of Petaurus breviceps to the library
# Adding 57 copies of Pteropus rufus to the library
# Adding 94 copies of Irania gutteralis to the library
# Adding 56 copies of Tayassu pecari to the library
# Adding 7 copies of Aonyx capensis to the library
# Adding 36 copies of Semnopithecus entellus to the library
# Adding 39 copies of Larus fuliginosus to the library
# Adding 50 copies of Aegypius tracheliotus to the library
# Adding 41 copies of Cebus albifrons to the library
# Adding 34 copies of Felis concolor to the library
# Adding 97 copies of Canis dingo to the library
# Adding 9 copies of Ciconia episcopus to the library
# Adding 42 copies of Larus fuliginosus to the library
# Adding 9 copies of Phalaropus fulicarius to the library
# Adding 80 copies of Milvus migrans to the library
# Adding 84 copies of Bucephala clangula to the library
# Logged in to Angelina Comello successfully
