# %%
from IPython.display import HTML, clear_output, display, ProgressBar
from jinja2 import Environment, FileSystemLoader

env = Environment(loader=FileSystemLoader("../src/screens/v3"))
filename = "employee"
filename += ".j2"
template = env.get_template(filename)
html = template.render(
    {"userName": "John Doe", "userEmail": "123@xyz.com", "orders": [{
        'order_id': '123',
        'customer_name': 'John Doe',
        'item_count': '20',
        'total': '2000',
    }]}
)
display(HTML(html))
# Out:
# <div class="container">
#     <h1 id="PageTitle">EMPLOYEE HOMEPAGE</h1>
#     <div class="textContainer">
#         <span style="font-size: 3rem;">Logged in as John Doe,</span>
#         <span style="font-size: 1rem;">Email: 123@xyz.com</span>
#     </div>
#     <div class="btnContainer">
#         <button>Confirm Order</button>
#         <button>Logout</button>
#     </div>
#     <div class="cartContainer">
#         <div class="cartHeader"></div>
#         <div class="cartItems">
#             <table class="cartTable">
#                 <thead>
#                     <tr>
#                         <th>Order ID</th>
#                         <th>Ordered By</th>
#                         <th>Items</th>
#                         <th>Total</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                     <tr>
#                         <td>123</td>
#                         <td>John Doe</td>
#                         <td>20</td>
# ...
